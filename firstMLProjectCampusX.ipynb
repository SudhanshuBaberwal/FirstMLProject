# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_555/1472378890.py in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_555/1472378890.py in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# #STEPS
# # preprocess + EDA +  Feature Selection
# # Extract input and output cols
# # Scale the Values
# # Train test split
# # Train the model
# # Evaluate the model/model selection
# # deploy the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'] , c = df['placement'])

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(X , Y , test_size = 0.1)
# Out:
# [    cgpa     iq
#  10   6.0   45.0
#  94   4.7   52.0
#  41   5.4  114.0
#  27   6.0  124.0
#  8    6.1  156.0
#  ..   ...    ...
#  21   7.1  151.0
#  22   4.9  120.0
#  78   6.1   81.0
#  61   7.3  137.0
#  32   7.0  139.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  62   6.0  102.0
#  7    5.0   63.0
#  81   5.4  107.0
#  16   5.2  224.0
#  85   5.8  166.0
#  5    7.1   48.0
#  53   8.3  168.0
#  73   4.9   61.0
#  19   5.2  132.0
#  99   6.2  113.0,
#  10    1
#  94    0
#  41    0
#  27    1
#  8     0
#       ..
#  21    1
#  22    0
#  78    0
#  61    1
#  32    1
#  Name: placement, Length: 90, dtype: int64,
#  62    0
#  7     0
#  81    0
#  16    0
#  85    1
#  5     1
#  53    1
#  73    0
#  19    0
#  99    1
#  Name: placement, dtype: int64]

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 26   7.0  199.0
# 32   7.0  139.0
# 87   5.7  132.0
# 27   6.0  124.0
# 50   3.5  233.0
# ..   ...    ...
# 11   6.9  138.0
# 41   5.4  114.0
# 89   4.9  151.0
# 88   4.4  149.0
# 47   5.2  161.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 26    1
# 32    1
# 87    1
# 27    1
# 50    0
#      ..
# 11    1
# 41    0
# 89    0
# 88    0
# 47    0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.8981053 ,  1.84115067],
#        [ 0.8981053 ,  0.31580338],
#        [-0.25914492,  0.1378462 ],
#        [ 0.00791282, -0.06553344],
#        [-2.21756836,  2.70551414],
#        [ 1.34320153,  0.08700129],
#        [ 0.09693207,  0.74798512],
#        [ 1.34320153,  0.79883003],
#        [ 0.80908605,  0.31580338],
#        [ 0.00791282, -1.54003582],
#        [ 1.43222078,  0.03615638],
#        [-1.06031815,  1.07847703],
#        [ 0.7200668 ,  0.36664829],
#        [-0.61522191, -0.1418008 ],
#        [ 0.45300906, -2.27728701],
#        [ 0.98712454,  0.62087284],
#        [ 1.87731702,  1.00220966],
#        [ 0.27497056, -0.59940499],
#        [-1.14933739, -1.89595019],
#        [-0.52620266,  0.31580338],
#        [-1.50541438,  1.86657313],
#        [-0.17012567,  1.00220966],
#        [ 0.54202831, -0.16722326],
#        [-0.9712989 , -0.16722326],
#        [ 1.78829777, -1.20954391],
#        [-0.70424116, -0.9298969 ],
#        [ 2.23339401, -0.16722326],
#        [-0.7932604 ,  1.25643421],
#        [ 1.43222078, -0.95531936],
#        [-0.9712989 , -1.66714809],
#        [ 0.09693207, -0.59940499],
#        [ 1.16516304, -1.03158672],
#        [-1.06031815, -0.3706029 ],
#        [-0.25914492,  0.34122584],
#        [-0.70424116,  0.1378462 ],
#        [ 0.09693207,  0.1378462 ],
#        [-0.9712989 ,  1.76488331],
#        [ 0.45300906,  0.84967494],
#        [ 0.54202831,  0.29038093],
#        [ 0.00791282, -0.62482745],
#        [ 0.09693207, -1.158699  ],
#        [ 0.45300906, -0.9298969 ],
#        [ 0.8981053 , -0.3706029 ],
#        [-1.14933739, -0.1418008 ],
#        [ 0.63104755,  1.40896894],
#        [-0.25914492,  1.07847703],
#        [ 0.7200668 , -0.09095589],
#        [-0.61522191, -0.31975799],
#        [ 0.8981053 ,  1.23101176],
#        [-0.70424116, -0.42144781],
#        [ 0.36398981,  0.36664829],
#        [-1.77247213, -1.31123373],
#        [ 0.80908605, -0.77736217],
#        [-1.06031815,  0.9259423 ],
#        [ 1.16516304, -1.9467951 ],
#        [-0.08110643, -0.52313763],
#        [ 0.36398981, -0.26891308],
#        [ 0.7200668 , -0.9298969 ],
#        [-0.25914492,  0.4174932 ],
#        [ 1.87731702,  0.57002793],
#        [ 1.16516304,  0.26495847],
#        [-0.88227965, -0.90447445],
#        [ 0.63104755,  0.69714021],
#        [-1.06031815,  0.36664829],
#        [-0.9712989 ,  0.72256266],
#        [ 1.61025928, -0.31975799],
#        [-0.70424116,  2.47671205],
#        [ 0.00791282, -2.07390737],
#        [-0.7932604 , -1.54003582],
#        [-0.52620266, -0.49771517],
#        [ 0.00791282,  0.57002793],
#        [-0.88227965, -0.21806817],
#        [ 0.45300906,  0.08700129],
#        [-0.7932604 ,  0.03615638],
#        [-0.88227965, -1.61630318],
#        [-1.14933739, -1.00616427],
#        [-0.52620266,  0.21411356],
#        [-1.41639514, -2.15017474],
#        [ 2.05535551,  1.05305457],
#        [ 0.7200668 , -0.3706029 ],
#        [-2.39560686,  1.4343914 ],
#        [ 0.18595132, -0.34518044],
#        [ 1.25418229,  0.1378462 ],
#        [ 0.27497056,  0.03615638],
#        [-1.23835664,  0.49376057],
#        [ 0.80908605,  0.29038093],
#        [-0.52620266, -0.31975799],
#        [-0.9712989 ,  0.62087284],
#        [-1.41639514,  0.57002793],
#        [-0.70424116,  0.87509739]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.9712989 ,  0.18869111],
#        [-1.77247213, -0.67567236],
#        [ 1.16516304, -0.26891308],
#        [ 1.34320153, -1.66714809],
#        [-1.86149137, -0.44687026],
#        [-0.17012567,  0.39207075],
#        [ 0.98712454, -1.99764001],
#        [ 0.8981053 , -1.59088073],
#        [ 0.27497056,  0.01073393],
#        [ 0.09693207, -1.56545827]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train , Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 40    0
# 18    0
# 72    1
# 44    1
# 31    0
# 4     0
# 5     1
# 64    1
# 70    1
# 56    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test , y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train , Y_train.values , clf = clf , legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf , open('model.pkl' , 'wb'))
